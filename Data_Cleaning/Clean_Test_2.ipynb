# %%
# Dependencies and Setup
import pandas as pd

# %%
#load data
csv_load = ("../ResourcesFull/stats2008.csv")
db_2021 = pd.read_csv(csv_load, encoding = "ISO-8859-1")

# %%
db_2021
# Out:
#       Rk                     Player Pos  Age   Tm   G  GS    MP   FG   FGA  \
# 0      1       Alex Acker\ackeral01  SG   26  TOT  25   0   8.0  1.2   3.0
# 1      1       Alex Acker\ackeral01  SG   26  DET   7   0   2.9  0.6   1.6
# 2      1       Alex Acker\ackeral01  SG   26  LAC  18   0   9.9  1.4   3.6
# 3      2     Hassan Adams\adamsha01  SG   24  TOR  12   0   4.3  0.3   1.1
# 4      3    Arron Afflalo\afflaar01  SG   23  DET  74   8  16.7  1.8   4.1
# ..   ...                        ...  ..  ...  ...  ..  ..   ...  ...   ...
# 577  441    Julian Wright\wrighju01  SF   21  NOH  54  19  14.3  2.0   4.3
# 578  442  Lorenzen Wright\wrighlo02   C   33  CLE  17   2   7.4  0.6   1.6
# 579  443       Nick Young\youngni01  SG   23  WAS  82   5  22.4  4.1   9.2
# 580  444   Thaddeus Young\youngth01  PF   20  PHI  75  71  34.4  6.3  12.8
# 581  445            Sun Yue\yuesu01  SG   23  LAL  10   0   2.8  0.3   1.1
#
#      ...  DRB  TRB  AST  STL  BLK  TOV   PF   PTS    YR  GMSCR
# ...

# %%
db_2021[["Player","Player_ID"]] = db_2021['Player'].str.split("\\", 1, expand=True)
db_2021.head()
# Out:
#    Rk         Player Pos  Age   Tm   G  GS    MP   FG  FGA  ...  TRB  AST  \
# 0   1     Alex Acker  SG   26  TOT  25   0   8.0  1.2  3.0  ...  1.0  0.5
# 1   1     Alex Acker  SG   26  DET   7   0   2.9  0.6  1.6  ...  0.3  0.1
# 2   1     Alex Acker  SG   26  LAC  18   0   9.9  1.4  3.6  ...  1.2  0.6
# 3   2   Hassan Adams  SG   24  TOR  12   0   4.3  0.3  1.1  ...  0.6  0.1
# 4   3  Arron Afflalo  SG   23  DET  74   8  16.7  1.8  4.1  ...  1.8  0.6
#
#    STL  BLK  TOV   PF  PTS    YR  GMSCR  Player_ID
# 0  0.2  0.2  0.3  0.4  2.9  2008   1.60  ackeral01
# 1  0.3  0.1  0.0  0.0  1.3  2008   0.40  ackeral01
# 2  0.2  0.2  0.4  0.5  3.5  2008   1.94  ackeral01
# 3  0.1  0.1  0.3  0.3  0.9  2008  -0.04  adamsha01
# 4  0.4  0.2  0.6  1.9  4.9  2008   3.03  afflaar01
#
# [5 rows x 33 columns]

# %%
#removing players with less the half a season of games 
#(filtering players with too few games, players that were traded midseason
game_cutoff = 43
db_2021[db_2021["G"] > game_cutoff]
# Out:
#       Rk             Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  TRB  \
# 4      3      Arron Afflalo  SG   23  DET  74   8  16.7  1.8   4.1  ...  1.8
# 8      7  LaMarcus Aldridge  PF   23  POR  81  81  37.1  7.4  15.3  ...  7.5
# 9      8      Joe Alexander  SF   22  MIL  59   0  12.1  1.7   4.2  ...  1.9
# 10     9        Malik Allen  PF   30  MIL  49   3  11.8  1.5   3.5  ...  2.1
# 11    10         Ray Allen*  SG   33  BOS  79  79  36.4  6.3  13.2  ...  3.5
# ..   ...                ...  ..  ...  ...  ..  ..   ...  ...   ...  ...  ...
# 573  437  Metta World Peace  SF   29  HOU  69  55  35.5  6.0  15.0  ...  5.2
# 574  438     Antoine Wright  SF   24  DAL  65  53  23.9  2.8   6.6  ...  2.1
# 577  441      Julian Wright  SF   21  NOH  54  19  14.3  2.0   4.3  ...  2.8
# 579  443         Nick Young  SG   23  WAS  82   5  22.4  4.1   9.2  ...  1.8
# 580  444     Thaddeus Young  PF   20  PHI  75  71  34.4  6.3  12.8  ...  5.0
#
# ...

# %%
db_2021_filtered = db_2021[db_2021["G"] > game_cutoff]
db_2021_filtered
# Out:
#       Rk             Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  TRB  \
# 4      3      Arron Afflalo  SG   23  DET  74   8  16.7  1.8   4.1  ...  1.8
# 8      7  LaMarcus Aldridge  PF   23  POR  81  81  37.1  7.4  15.3  ...  7.5
# 9      8      Joe Alexander  SF   22  MIL  59   0  12.1  1.7   4.2  ...  1.9
# 10     9        Malik Allen  PF   30  MIL  49   3  11.8  1.5   3.5  ...  2.1
# 11    10         Ray Allen*  SG   33  BOS  79  79  36.4  6.3  13.2  ...  3.5
# ..   ...                ...  ..  ...  ...  ..  ..   ...  ...   ...  ...  ...
# 573  437  Metta World Peace  SF   29  HOU  69  55  35.5  6.0  15.0  ...  5.2
# 574  438     Antoine Wright  SF   24  DAL  65  53  23.9  2.8   6.6  ...  2.1
# 577  441      Julian Wright  SF   21  NOH  54  19  14.3  2.0   4.3  ...  2.8
# 579  443         Nick Young  SG   23  WAS  82   5  22.4  4.1   9.2  ...  1.8
# 580  444     Thaddeus Young  PF   20  PHI  75  71  34.4  6.3  12.8  ...  5.0
#
# ...

# %%
#player_names checks (now less vital with ids)
player_names = db_2021_filtered["Player"]

# %%
#checking allstar player
player_names[player_names.str.match(".*\*")]
# Out:
# 11            Ray Allen*
# 70           Chris Bosh*
# 89          Kobe Bryant*
# 165          Tim Duncan*
# 191       Kevin Garnett*
# 199       Manu Ginóbili*
# 241          Grant Hill*
# 263       Allen Iverson*
# 265       Allen Iverson*
# 300          Jason Kidd*
# 365            Yao Ming*
# 383          Steve Nash*
# 402    Shaquille O'Neal*
# 421         Paul Pierce*
# 541         Ben Wallace*
# Name: Player, dtype: object

# %%
#checking for special characters the may need hands on checks
player_names[player_names.str.contains("[^\w'\-\.\* ]", regex=True)]
# Out:
# 53         Andris Biedri?
# 160           Goran Dragi?
# 277            Marko Jari?
# 307           Nenad Krsti?
# 358          Darko Mili?i?
# 386       Rasho Nesterovi?
# 414         Sasha Pavlovi?
# 431    Vladimir Radmanovi?
# 432    Vladimir Radmanovi?
# 505        Peja Stojakovi?
# 529          Hedo Türko?lu
# 532              Roko Uki?
# 537          Sasha Vuja?i?
# Name: Player, dtype: object

# %%
player_names.head(35)
# Out:
# 4         Arron Afflalo
# 8     LaMarcus Aldridge
# 9         Joe Alexander
# 10          Malik Allen
# 11           Ray Allen*
# 12           Tony Allen
# 14         Rafer Alston
# 15         Rafer Alston
# 17         Lou Amundson
# 18       Chris Andersen
# 19        Ryan Anderson
# 20      Carmelo Anthony
# 21         Joel Anthony
# 23         Trevor Ariza
# 24     Hilton Armstrong
# 25       Darrell Arthur
# 29        D.J. Augustin
# 30     Kelenna Azubuike
# 31      Renaldo Balkman
# 35      Leandro Barbosa
# 36           J.J. Barea
# 37      Andrea Bargnani
# 38          Matt Barnes
# 39          Brent Barry
# 40         Brandon Bass
# 42          Tony Battie
# 43        Shane Battier
# 44        Nicolas Batum
# 45       Jerryd Bayless
# 46      Michael Beasley
# 48         Charlie Bell
# 49            Raja Bell
# 51            Raja Bell
# 52           Mike Bibby
# 53      Andris Biedri?
# Name: Player, dtype: object

# %%
#correcting names
corrected_names = []
for player in player_names:
    if player.find("*") != (-1):
        player = player.replace("*","")
        print(player)
    elif player == "Ömer A??k":
        player = player.replace("A??k","Asik")
        print(player)
    corrected_names.append(player)
# Out:
# Ray Allen
# Chris Bosh
# Kobe Bryant
# Tim Duncan
# Kevin Garnett
# Manu Ginóbili
# Grant Hill
# Allen Iverson
# Allen Iverson
# Jason Kidd
# Yao Ming
# Steve Nash
# Shaquille O'Neal
# Paul Pierce
# Ben Wallace

# %%
corrected_names
# Out:
# ['Arron Afflalo',
#  'LaMarcus Aldridge',
#  'Joe Alexander',
#  'Malik Allen',
#  'Ray Allen',
#  'Tony Allen',
#  'Rafer Alston',
#  'Rafer Alston',
#  'Lou Amundson',
#  'Chris Andersen',
#  'Ryan Anderson',
#  'Carmelo Anthony',
#  'Joel Anthony',
#  'Trevor Ariza',
#  'Hilton Armstrong',
#  'Darrell Arthur',
#  'D.J. Augustin',
#  'Kelenna Azubuike',
#  'Renaldo Balkman',
#  'Leandro Barbosa',
#  'J.J. Barea',
#  'Andrea Bargnani',
#  'Matt Barnes',
#  'Brent Barry',
#  'Brandon Bass',
#  'Tony Battie',
#  'Shane Battier',
#  'Nicolas Batum',
#  'Jerryd Bayless',
#  'Michael Beasley',
#  'Charlie Bell',
#  'Raja Bell',
#  'Raja Bell',
#  'Mike Bibby',
#  'Andris Biedri?\x9a',
#  'Chauncey Billups',
#  'Chauncey Billups',
#  'Steve Blake',
#  'Andray Blatche',
#  'Keith Bogans',
#  'Matt Bonner',
#  'Josh Boone',
#  'Chris Bosh',
#  'Bruce Bowen',
#  'Ronnie Brewer',
#  'Aaron Brooks',
#  'Bobby Brown',
#  'Bobby Brown',
#  'Devin Brown',
#  'Kwame Brown',
#  'Shannon Brown',
# ...

# %%
db_2021_filtered.isna().sum()
# Out:
# Rk            0
# Player        0
# Pos           0
# Age           0
# Tm            0
# G             0
# GS            0
# MP            0
# FG            0
# FGA           0
# FG%           0
# 3P            0
# 3PA           0
# 3P%          27
# 2P            0
# 2PA           0
# 2P%           0
# eFG%          0
# FT            0
# FTA           0
# FT%           0
# ORB           0
# DRB           0
# TRB           0
# AST           0
# STL           0
# BLK           0
# TOV           0
# PF            0
# PTS           0
# YR            0
# GMSCR         0
# Player_ID     0
# dtype: int64

# %%
db_2021_filtered[db_2021_filtered["3P%"].isna()]
# Out:
#       Rk           Player   Pos  Age   Tm   G  GS    MP   FG   FGA  ...   TRB  \
# 21    18     Joel Anthony     C   26  MIA  65  28  16.1  0.9   1.8  ...   3.0
# 65    52       Josh Boone     C   24  NJN  62   7  16.0  1.8   3.5  ...   4.2
# 85    66      Kwame Brown     C   26  DET  58  30  17.2  1.6   2.9  ...   5.0
# 93    72     Andrew Bynum     C   21  LAL  50  50  28.9  5.6  10.0  ...   8.0
# 105   82   Tyson Chandler     C   26  NOH  45  45  32.1  3.6   6.3  ...   8.7
# 131   98    Erick Dampier     C   33  DAL  80  80  23.0  2.3   3.5  ...   7.1
# 150  111    DeSagana Diop     C   27  TOT  75   1  13.8  1.0   2.3  ...   3.6
# 227  173    Udonis Haslem    PF   28  MIA  75  75  34.1  4.4   8.6  ...   8.2
# 237  181      Roy Hibbert     C   22  IND  70  42  14.4  2.8   6.0  ...   3.5
# 238  182     J.J. Hickson     C   20  CLE  62   0  11.4  1.6   3.1  ...   2.7
# 244  188     Ryan Hollins     C   24  TOT  45   3   9.9  1.1   2.1  ...   2.2
# ...

# %%
#fill NA 3-pointers with zeroes (all cases have been from 0 3P shots attempted)
db_2021_filtered["3P%"] = db_2021_filtered["3P%"].fillna(0)
db_2021_filtered["FT%"] = db_2021_filtered["FT%"].fillna(0)
# Out:
# C:\Users\ricky\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
db_2021_filtered
# Out:
#       Rk             Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  TRB  \
# 4      3      Arron Afflalo  SG   23  DET  74   8  16.7  1.8   4.1  ...  1.8
# 8      7  LaMarcus Aldridge  PF   23  POR  81  81  37.1  7.4  15.3  ...  7.5
# 9      8      Joe Alexander  SF   22  MIL  59   0  12.1  1.7   4.2  ...  1.9
# 10     9        Malik Allen  PF   30  MIL  49   3  11.8  1.5   3.5  ...  2.1
# 11    10         Ray Allen*  SG   33  BOS  79  79  36.4  6.3  13.2  ...  3.5
# ..   ...                ...  ..  ...  ...  ..  ..   ...  ...   ...  ...  ...
# 573  437  Metta World Peace  SF   29  HOU  69  55  35.5  6.0  15.0  ...  5.2
# 574  438     Antoine Wright  SF   24  DAL  65  53  23.9  2.8   6.6  ...  2.1
# 577  441      Julian Wright  SF   21  NOH  54  19  14.3  2.0   4.3  ...  2.8
# 579  443         Nick Young  SG   23  WAS  82   5  22.4  4.1   9.2  ...  1.8
# 580  444     Thaddeus Young  PF   20  PHI  75  71  34.4  6.3  12.8  ...  5.0
#
# ...

# %%
#moving id to front
move_col = db_2021_filtered.pop('Player_ID')
db_2021_filtered.insert(1, 'Player_ID', move_col)

# %%
db_2021_filtered
# Out:
#       Rk  Player_ID             Player Pos  Age   Tm   G  GS    MP   FG  ...  \
# 4      3  afflaar01      Arron Afflalo  SG   23  DET  74   8  16.7  1.8  ...
# 8      7  aldrila01  LaMarcus Aldridge  PF   23  POR  81  81  37.1  7.4  ...
# 9      8  alexajo01      Joe Alexander  SF   22  MIL  59   0  12.1  1.7  ...
# 10     9  allenma01        Malik Allen  PF   30  MIL  49   3  11.8  1.5  ...
# 11    10  allenra02         Ray Allen*  SG   33  BOS  79  79  36.4  6.3  ...
# ..   ...        ...                ...  ..  ...  ...  ..  ..   ...  ...  ...
# 573  437  artesro01  Metta World Peace  SF   29  HOU  69  55  35.5  6.0  ...
# 574  438  wrighan01     Antoine Wright  SF   24  DAL  65  53  23.9  2.8  ...
# 577  441  wrighju01      Julian Wright  SF   21  NOH  54  19  14.3  2.0  ...
# 579  443  youngni01         Nick Young  SG   23  WAS  82   5  22.4  4.1  ...
# 580  444  youngth01     Thaddeus Young  PF   20  PHI  75  71  34.4  6.3  ...
#
# ...

# %%
db_2021_filtered["Player_ID"].nunique()
# Out:
# 317

# %%
db_2021_filtered = db_2021_filtered[db_2021_filtered.Tm != "TOT"]

# %%
db_2021_filtered["Player_ID"].duplicated().sum()
# Out:
# 0

# %%
db_2021_filtered = db_2021_filtered.set_index('Rk')
db_2021_filtered
# Out:
#      Player_ID             Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
# Rk                                                                        ...
# 3    afflaar01      Arron Afflalo  SG   23  DET  74   8  16.7  1.8   4.1  ...
# 7    aldrila01  LaMarcus Aldridge  PF   23  POR  81  81  37.1  7.4  15.3  ...
# 8    alexajo01      Joe Alexander  SF   22  MIL  59   0  12.1  1.7   4.2  ...
# 9    allenma01        Malik Allen  PF   30  MIL  49   3  11.8  1.5   3.5  ...
# 10   allenra02         Ray Allen*  SG   33  BOS  79  79  36.4  6.3  13.2  ...
# ..         ...                ...  ..  ...  ...  ..  ..   ...  ...   ...  ...
# 437  artesro01  Metta World Peace  SF   29  HOU  69  55  35.5  6.0  15.0  ...
# 438  wrighan01     Antoine Wright  SF   24  DAL  65  53  23.9  2.8   6.6  ...
# 441  wrighju01      Julian Wright  SF   21  NOH  54  19  14.3  2.0   4.3  ...
# 443  youngni01         Nick Young  SG   23  WAS  82   5  22.4  4.1   9.2  ...
# ...

# %%
new_csv = "Test_Output/db_2021_clean2.csv"
db_2021_filtered.to_csv(new_csv, encoding = "ISO-8859-1")

# %%
#issues = db_2021_filtered[db_2021_filtered["Player_ID"].duplicated(keep=False)]
#duplicate_csv = "Test_Output/db_2021_duplicates.csv"
#issues.to_csv(duplicate_csv)
