# %%
# Dependencies and Setup
import pandas as pd

# %%
#load data test (change file names)

csv_load = ("../Resources/nba_pergame_11-12.csv")

db_test = pd.read_csv("../Resources/nba_pergame_11-12.csv", encoding = "ISO-8859-1")

# %%
db_test
# Out:
#       Rk             Player Pos  Age   Tm   G  GS    MP    FG   FGA  ...  \
# 0      1       Kevin Durant  SF   23  OKC  66  66  38.6   9.7  19.7  ...
# 1      2       Kobe Bryant*  SG   33  LAL  58  58  38.5   9.9  23.0  ...
# 2      3       LeBron James  SF   27  MIA  62  62  37.5  10.0  18.9  ...
# 3      4         Kevin Love  PF   23  MIN  55  55  39.0   8.6  19.3  ...
# 4      5  Russell Westbrook  PG   23  OKC  66  66  35.3   8.8  19.2  ...
# ..   ...                ...  ..  ...  ...  ..  ..   ...   ...   ...  ...
# 181  182     Damien Wilkins  SF   32  DET  60   2  15.4   1.3   3.2  ...
# 182  183          Ömer A??k   C   25  CHI  66   2  14.7   1.2   2.4  ...
# 183  184      Nazr Mohammed   C   34  OKC  63   1  11.0   1.3   2.7  ...
# 184  185       Reggie Evans  PF   31  LAC  56   0  13.8   0.6   1.3  ...
# 185  186       Ben Wallace*   C   37  DET  62  11  15.8   0.5   1.4  ...
#
#        FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF  PTS?
# 0    0.860  0.6  7.4   8.0  3.5  1.3  1.2  3.8  2.0  28.0
# 1    0.845  1.1  4.3   5.4  4.6  1.2  0.3  3.5  1.8  27.9
# 2    0.771  1.5  6.4   7.9  6.2  1.9  0.8  3.4  1.5  27.1
# 3    0.824  4.1  9.2  13.3  2.0  0.9  0.5  2.3  2.8  26.0
# 4    0.823  1.5  3.1   4.6  5.5  1.7  0.3  3.6  2.2  23.6
# ..     ...  ...  ...   ...  ...  ...  ...  ...  ...   ...
# 181  0.630  0.4  1.3   1.7  0.7  0.5  0.2  0.5  1.4   3.2
# 182  0.456  1.9  3.4   5.3  0.5  0.5  1.0  1.0  1.8   3.1
# 183  0.565  0.9  1.8   2.7  0.2  0.3  0.6  0.4  1.6   2.7
# 184  0.507  1.8  3.1   4.8  0.3  0.6  0.1  0.8  2.1   1.9
# 185  0.340  1.3  3.0   4.3  0.7  0.8  0.8  0.5  1.0   1.4
#
# [186 rows x 30 columns]

# %%
player_names = db_test["Player"]

# %%
#checking allstar player
player_names[player_names.str.match(".*\*")]
# Out:
# 1        Kobe Bryant*
# 13       Paul Pierce*
# 23        Chris Bosh*
# 33     Kevin Garnett*
# 37        Tim Duncan*
# 66        Steve Nash*
# 185      Ben Wallace*
# Name: Player, dtype: object

# %%
#checking for special characters the may need hands on checks
player_names[player_names.str.match("[^A-Za-z0-9_]")]
# Out:
# 182    Ömer A??k
# Name: Player, dtype: object

# %%
#correcting names
corrected_names = []
for player in player_names:
    if player.find("*") != (-1):
        player = player.replace("*","")
        print(player)
    elif player == "Ömer A??k":
        player = player.replace("A??k","Asik")
        print(player)
    corrected_names.append(player)
# Out:
# Kobe Bryant
# Paul Pierce
# Chris Bosh
# Kevin Garnett
# Tim Duncan
# Steve Nash
# Ömer Asik
# Ben Wallace

# %%
corrected_names
# Out:
# ['Kevin Durant',
#  'Kobe Bryant',
#  'LeBron James',
#  'Kevin Love',
#  'Russell Westbrook',
#  'Carmelo Anthony',
#  'LaMarcus Aldridge',
#  'Dirk Nowitzki',
#  'Deron Williams',
#  'Blake Griffin',
#  'Monta Ellis',
#  'David Lee',
#  'Chris Paul',
#  'Paul Pierce',
#  'Al Jefferson',
#  'Brandon Jennings',
#  'Rudy Gay',
#  'Josh Smith',
#  'Joe Johnson',
#  'Andrew Bynum',
#  'Danny Granger',
#  'Tony Parker',
#  'DeMarcus Cousins',
#  'Chris Bosh',
#  'Pau Gasol',
#  'Antawn Jamison',
#  'James Harden',
#  'DeMar DeRozan',
#  'Paul Millsap',
#  'Tyreke Evans',
#  'Ty Lawson',
#  'John Wall',
#  'Ryan Anderson',
#  'Kevin Garnett',
#  'Luis Scola',
#  'Greg Monroe',
#  'Marcin Gortat',
#  'Tim Duncan',
#  'Arron Afflalo',
#  'Jason Terry',
#  'Carlos Boozer',
#  'Lou Williams',
#  'Jordan Crawford',
#  'Marc Gasol',
#  'Nick Young',
#  'Al Harrington',
#  'Jamal Crawford',
#  'Nicolas Batum',
#  'Kris Humphries',
#  'Gerald Wallace',
#  'Wesley Matthews',
#  'Drew Gooden',
#  'Jrue Holiday',
#  'Ersan ?lyasova',
#  'Brandon Knight',
#  'Thaddeus Young',
#  'Roy Hibbert',
#  'David West',
#  'Mike Conley',
#  'Jared Dudley',
#  'Tayshaun Prince',
#  'Jeff Teague',
#  'MarShon Brooks',
#  'O.J. Mayo',
#  'Klay Thompson',
#  'Brandon Bass',
#  'Steve Nash',
#  'Andre Iguodala',
#  'Kemba Walker',
#  'Paul George',
#  'Anthony Morrow',
#  'Caron Butler',
#  'Jameer Nelson',
#  'Gordon Hayward',
#  'Marco Belinelli',
#  'Goran Dragi?',
#  'J.J. Redick',
#  'Isaiah Thomas',
#  'Courtney Lee',
#  'Raymond Felton',
#  'JaVale McGee',
#  'Ramon Sessions',
#  'Devin Harris',
#  'Tyson Chandler',
#  'Leandro Barbosa',
#  'Shannon Brown',
#  'Randy Foye',
#  'Elton Brand',
#  'Alonzo Gee',
#  'Shawn Marion',
#  'Channing Frye',
#  'Darren Collison',
#  'Dorell Wright',
#  'Marvin Williams',
#  'Joakim Noah',
#  'Vince Carter',
#  'Gary Neal',
#  'Mario Chalmers',
#  'Brandon Rush',
#  'Tony Allen',
#  'Andre Miller',
#  'Chase Budinger',
#  'Iman Shumpert',
#  'DeJuan Blair',
#  'Chandler Parsons',
#  'Evan Turner',
#  'Byron Mullens',
#  'Tyler Hansbrough',
#  'Glen Davis',
#  'Tiago Splitter',
#  'Richard Jefferson',
#  'Serge Ibaka',
#  'C.J. Miles',
#  'James Johnson',
#  'Danny Green',
#  'Jason Thompson',
#  'Greivis Vásquez',
#  'Corey Brewer',
#  'Derrick Williams',
#  'Derrick Favors',
#  'Landry Fields',
#  'Marreese Speights',
#  'Jonas Jerebko',
#  'Jodie Meeks',
#  'Tristan Thompson',
#  'Derrick Brown',
#  'Kyle Korver',
#  'Kawhi Leonard',
#  'Kevin Séraphin',
#  'Zaza Pachulia',
#  'Matt Barnes',
#  'Patrick Patterson',
#  'Taj Gibson',
#  'Metta World Peace',
#  'Avery Bradley',
#  'Jimmer Fredette',
#  'Samuel Dalembert',
#  'Markieff Morris',
#  'DeAndre Jordan',
#  'Alec Burks',
#  'Omri Casspi',
#  'Amir Johnson',
#  'Ronnie Brewer',
#  'Norris Cole',
#  'D.J. White',
#  'Matt Bonner',
#  'Jason Maxiell',
#  'Ivan Johnson',
#  'Boris Diaw',
#  'Ed Davis',
#  'Sebastian Telfair',
#  'Al-Farouq Aminu',
#  'Wesley Johnson',
#  'Udonis Haslem',
#  'Beno Udrih',
#  'Ian Mahinmi',
#  'Ekpe Udoh',
#  'Derek Fisher',
#  'Daequan Cook',
#  'Shaun Livingston',
#  'Robin Lopez',
#  'Dahntay Jones',
#  'Bismack Biyombo',
#  'Dante Cunningham',
#  'Sundiata Gaines',
#  'Kendrick Perkins',
#  'Marcus Camby',
#  'Shane Battier',
#  'Jan Veselý',
#  'Enes Freedom',
#  'Chris Singleton',
#  'Shelden Williams',
#  'Nick Collison',
#  'Quincy Pondexter',
#  'Johan Petro',
#  'Chris Duhon',
#  'Shelvin Mack',
#  'Lou Amundson',
#  'Dominic McGuire',
#  'Joel Anthony',
#  'Troy Murphy',
#  'Damien Wilkins',
#  'Ömer Asik',
#  'Nazr Mohammed',
#  'Reggie Evans',
#  'Ben Wallace']

# %%
db_test.isna().sum()
# Out:
# Rk         0
# Player     0
# Pos        0
# Age        0
# Tm         0
# G          0
# GS         0
# MP         0
# FG         0
# FGA        0
# FG%        0
# 3P         0
# 3PA        0
# 3P%       16
# 2P         0
# 2PA        0
# 2P%        0
# eFG%       0
# FT         0
# FTA        0
# FT%        0
# ORB        0
# DRB        0
# TRB        0
# AST        0
# STL        0
# BLK        0
# TOV        0
# PF         0
# PTS?       0
# dtype: int64

# %%
db_test[db_test["3P%"].isna()]
# Out:
#       Rk            Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...    FT%  \
# 48    49    Kris Humphries  PF   26  NJN  62  62  34.9  5.2  10.8  ...  0.752
# 65    66      Brandon Bass  PF   26  BOS  59  39  31.7  5.1  10.7  ...  0.810
# 80    81      JaVale McGee   C   24  TOT  61  45  25.2  5.0   9.0  ...  0.461
# 109  110    Tiago Splitter   C   27  SAS  59   2  19.0  3.6   5.8  ...  0.691
# 119  120    Derrick Favors  PF   20  UTA  65   9  21.2  3.4   6.8  ...  0.649
# 129  130     Zaza Pachulia   C   27  ATL  58  44  28.3  2.9   5.8  ...  0.741
# 132  133        Taj Gibson  PF   26  CHI  63   0  20.4  3.2   6.4  ...  0.622
# 153  154     Udonis Haslem  PF   31  MIA  64  10  24.8  2.4   5.6  ...  0.814
# 160  161       Robin Lopez   C   23  PHO  64   0  14.0  1.9   4.2  ...  0.714
# 162  163   Bismack Biyombo   C   19  CHA  63  41  23.1  2.0   4.4  ...  0.483
# 165  166  Kendrick Perkins   C   27  OKC  65  65  26.8  2.0   4.0  ...  0.652
# 171  172  Shelden Williams   C   28  NJN  58  35  22.0  1.7   3.5  ...  0.731
# 177  178      Lou Amundson  PF   29  IND  60   0  12.6  1.5   3.5  ...  0.427
# 179  180      Joel Anthony   C   29  MIA  64  51  21.1  1.3   2.4  ...  0.690
# 182  183         Ömer A??k   C   25  CHI  66   2  14.7  1.2   2.4  ...  0.456
# 184  185      Reggie Evans  PF   31  LAC  56   0  13.8  0.6   1.3  ...  0.507
#
#      ORB  DRB   TRB  AST  STL  BLK  TOV   PF  PTS?
# 48   3.8  7.2  11.0  1.5  0.8  1.2  1.9  2.8  13.8
# 65   1.6  4.6   6.2  0.9  0.6  0.9  1.1  2.3  12.5
# 80   2.7  5.1   7.8  0.5  0.6  2.2  1.4  2.7  11.3
# 109  1.6  3.6   5.2  1.1  0.4  0.8  1.5  2.3   9.3
# 119  2.4  4.1   6.5  0.7  0.6  1.0  1.6  2.2   8.8
# 129  2.7  5.2   7.9  1.4  0.9  0.5  1.4  3.0   7.8
# 132  2.1  3.1   5.3  0.7  0.4  1.3  1.0  2.1   7.7
# 153  1.8  5.5   7.3  0.7  0.5  0.4  0.9  2.2   6.0
# 160  1.4  1.9   3.3  0.3  0.3  0.9  0.7  2.0   5.4
# 162  1.8  4.0   5.8  0.4  0.3  1.8  1.1  2.3   5.2
# 165  1.8  4.7   6.6  1.2  0.4  1.1  1.8  2.9   5.1
# 171  2.4  3.6   6.0  0.6  0.8  0.7  1.1  2.6   4.6
# 177  1.6  2.1   3.7  0.2  0.5  0.7  0.8  2.1   3.6
# 179  1.6  2.3   3.9  0.1  0.6  1.3  0.7  2.0   3.4
# 182  1.9  3.4   5.3  0.5  0.5  1.0  1.0  1.8   3.1
# 184  1.8  3.1   4.8  0.3  0.6  0.1  0.8  2.1   1.9
#
# [16 rows x 30 columns]
